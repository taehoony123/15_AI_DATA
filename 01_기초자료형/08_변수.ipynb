# %%
# 변수는 어떻게 만들까?
a = 1
b = "python"
c = [1,2,3]

# 변수이름 = 변수에 저장할 값

# %%
# 변수 명명 규칙
# 1. 영문자, 숫자, "_" 만 가능하다
# 2. 숫자로 변수명 시작할 수 없다.
# 3. 예약어는 사용할 수 없다 (list, print, del ...)
# 4. 대소문자 구분한다.

_private = "비공개"
userName = "ken" #소문자 u 나오다가 대문자 N이 나오는걸 카멜 구조라고함
user_name = "ken" # 이게 가장 무난하다
UserName = "ken"
# user-name 이거는 안된다. 음수로 이해함
s1 = 2
S1 = 2

a = 12 #사실 a라는 말은 코드가 길어지면 이해하기 어려워서 좋은 변수명은 아니다.

# %%
# 변수를 만드는 여러가지 방법
a,b = "python","life"
print(a)
print(b)
print(type(a))
# Out:
# python
# life
# <class 'str'>

# %%
[a,b] = ["python","life"]
print(a)
print(type(a))
# Out:
# python
# <class 'str'>

# %%
a = b = "python"
print(b)
print(a)
# Out:
# python
# python

# %%
a = 3
b = 5
a , b = b , a

print(a)
print(b)
# Out:
# 5
# 3
