# %%
# 딕셔너리는 어떻게 만들까
# {key1: value1, key2 : value2}

dic = {
	"name" : "ken",
	"phone" : "010-****-****",
	"birth" : "01/01",
}

print(dic)
# Out:
# {'name': 'ken', 'phone': '010-****-****', 'birth': '01/01'}

# %%
# 딕셔너리 쌍 추가하기
a = {1: "a"}
a[2] = "b"
print(a)
# Out:
# {1: 'a', 2: 'b'}
