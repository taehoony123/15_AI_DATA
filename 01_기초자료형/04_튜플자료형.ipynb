# %%
# 튜플은 어떻게 만들까?
t1 = ()
t2 = (1,) # 리스트 일때 L1 = [1]
t3 = (1,2,3)
t4 = 1,2,3
t5 = 1,
t6 = 1
t7 = ("a","b",("ab","cd"))
print(type(t4))
print(type(t2))
print(type(t5))
print(type(t6))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>

# %%
# 튜플의 요솟값을 지우거나 변경하려고하면 어떻게 될까?
t1 = (1,2,"a","b")
# 지우거나 변경 안된다 튜플의 특징

# %%
# 인덱싱하기
t1 = (1,2,"a","b")
t1[2]
# Out:
# 'a'

# %%
# 슬라이싱
t1 = (1,2,"a","b")
t1[2:]
# Out:
# ('a', 'b')

# %%
# 튜플 더하기
t1 = (1,2,3)
t2 = (4,5,6)
t1 + t2
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# 튜플 곱하기
t1 = (1,2,3)
t1 * 3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
# 튜플의 길이 구하기
t1 = (1,2,3)
len(t1)
# Out:
# 3
